# %%
import matplotlib.pyplot as plt

# %%
d20= [[0.8, 0.6992372582126237], [0.85, 0.6729661801718192], [0.9, 0.613884543151913], [0.95, 0.52898610982118], [1.0, 0.443799430615774], [1.05, 0.3746021785990727]]
d50 =[[0.8, 0.7194890398885997], [0.85, 0.7310803619695931], [0.9, 0.7425602941239089], [0.95, 0.6960695764881449], [1.0, 0.5245934080529719], [1.05, 0.39712895513824414]]
d80=[[0.8, 0.02718472331231713], [0.85, 0.7316538839020994], [0.9, 0.7515293614444798], [0.95, 0.7660821526542985], [1.0, 0.5648972465578213], [1.05, 0.3996924137904157]]
d100=[[0.8, 0.02637042649466993], [0.85, 0.03855688484320854], [0.9, 0.7519046043167077], [0.95, 0.7828743294366096], [1.0,0.5838739119330594], [1.05, 0.40000758267998515]]
d150=[[0.8, 0.026370426408818946], [0.85, 0.03851163242270991], [0.9, 0.058810463586811516], [0.95, 0.7926534160358737], [1.0, 0.6181730242234394], [1.05, 0.4001339155427169]]
d200=[[0.8, 0.02637042638333119], [0.85, 0.038511632417359803], [0.9, 0.05881042701426582], [0.95, 0.7934670372514201], [1.0, 0.6424025003302891], [1.05, 0.4001407790591848]]

# %%
x20 = [ i[0] for i in d20]
y20 = [ i[1] for i in d20]

x50 = [ i[0] for i in d50]
y50 = [ i[1] for i in d50]

x80 = [ i[0] for i in d80]
y80 = [ i[1] for i in d80]

x100 = [ i[0] for i in d100]
y100 = [ i[1] for i in d100]

x150 = [ i[0] for i in d150]
y150 = [ i[1] for i in d150]

x200 = [ i[0] for i in d200]
y200 = [ i[1] for i in d200]

# %%
import numpy as np 
print(d20)
d20a = np.array(d20)

print(d20a[:,1])
# Out:
# [[0.8, 0.6992372582126237], [0.85, 0.6729661801718192], [0.9, 0.613884543151913], [0.95, 0.52898610982118], [1.0, 0.443799430615774], [1.05, 0.3746021785990727]]
# [0.69923726 0.67296618 0.61388454 0.52898611 0.44379943 0.37460218]

# %%
plt.plot((x20),(y20))
plt.plot((x20),(y50))
plt.plot((x20),(y80))
plt.plot((x20),(y100))
plt.plot((x20),(y150))
plt.plot((x20),(y200))

# %%
ggs= (0.8, 0.85, 0.9, .91, .92, .93, .94,  0.95, 0.96, 0.97, 0.98, 0.99, 1.0, 1.01, 1.02, 1