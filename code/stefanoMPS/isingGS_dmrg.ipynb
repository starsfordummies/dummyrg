# %%
import numpy as np

import matplotlib.pyplot as plt
import myMPSstuff as mps
import myMPOstuff as mpo
import applMPOMPS as mpomps

import myDMRG as dmrg

from isingMPO import IsingMPO
from oned_ising_tenpy import example_DMRG_tf_ising_finite

# %%
LLL = 20

# maximum chi 
chiM = 40

gg = 0.4

# %%
# First do it with tenpy 
# Apply MPO to MPS operations 

"""
# Do it with tenpy 
E_tenpy, psi_tenpy, _ = example_DMRG_tf_ising_finite(LLL, gg, chiM)
Smid_tenpy = psi_tenpy.entanglement_entropy()[(LLL-1)//2]
"""
# Out:
# '\n# Do it with tenpy \nE_tenpy, psi_tenpy, _ = example_DMRG_tf_ising_finite(LLL, gg, chiM)\nSmid_tenpy = psi_tenpy.entanglement_entropy()[(LLL-1)//2]\n'

# %%
# Now my DMRG


psi = mps.myMPS(mps.randMPS(LLL))

Hising = mpo.myMPO(IsingMPO(LLL, J=1., g=gg))

dmrg.findGS_DMRG(Hising, psi)
# Out:
# -2 (2, 1, 2) (3, 1, 2, 2) (1, 1, 1) (2, 3, 2)
# -3 (4, 2, 2) (3, 3, 2, 2) (2, 3, 2) (4, 3, 4)
# -4 (5, 4, 2) (3, 3, 2, 2) (4, 3, 4) (5, 3, 5)
# -5 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -6 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -7 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -8 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -9 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -10 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -11 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -12 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -13 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -14 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -15 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -16 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -17 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -18 (5, 5, 2) (3, 3, 2, 2) (5, 3, 5) (5, 3, 5)
# -19 (4, 5, 2) (3, 3, 2, 2) (5, 3, 5) (4, 3, 4)
# -20 (2, 4, 2) (3, 3, 2, 2) (4, 3, 4) (2, 3, 2)
# -21 (1, 2, 2) (1, 3, 2, 2) (2, 3, 2) (1, 1, 1)
# (1, 1, 1) (1, 3, 2, 2) (3, 3, 2, 2) (4, 3, 4)
# chis = 1, 4
# working with chis 0 and 2, we will change chi 1
# chitrunc = 2
# Replacing A[0](1, 2, 2) with (1, 2, 2)
# Replacing A[1](2, 4, 2) with (2, 4, 2)
# updating left env, 0 elem from ..
# (2, 3, 2) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 2, 5
# working with chis 1 and 3, we will change chi 2
# chitrunc = 4
# Replacing A[1](2, 4, 2) with (2, 4, 2)
# Replacing A[2](4, 5, 2) with (4, 5, 2)
# updating left env, 1 elem from ..
# (4, 3, 4) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 4, 5
# working with chis 2 and 4, we will change chi 3
# chitrunc = 8
# Replacing A[2](4, 5, 2) with (4, 8, 2)
# Replacing A[3](5, 5, 2) with (8, 5, 2)
# updating left env, 2 elem from ..
# (8, 3, 8) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 8, 5
# working with chis 3 and 5, we will change chi 4
# chitrunc = 10
# Replacing A[3](8, 5, 2) with (8, 10, 2)
# Replacing A[4](5, 5, 2) with (10, 5, 2)
# updating left env, 3 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 4 and 6, we will change chi 5
# chitrunc = 10
# Replacing A[4](10, 5, 2) with (10, 10, 2)
# Replacing A[5](5, 5, 2) with (10, 5, 2)
# updating left env, 4 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 5 and 7, we will change chi 6
# chitrunc = 10
# Replacing A[5](10, 5, 2) with (10, 10, 2)
# Replacing A[6](5, 5, 2) with (10, 5, 2)
# updating left env, 5 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 6 and 8, we will change chi 7
# chitrunc = 10
# Replacing A[6](10, 5, 2) with (10, 10, 2)
# Replacing A[7](5, 5, 2) with (10, 5, 2)
# updating left env, 6 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 7 and 9, we will change chi 8
# chitrunc = 10
# Replacing A[7](10, 5, 2) with (10, 10, 2)
# Replacing A[8](5, 5, 2) with (10, 5, 2)
# updating left env, 7 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 8 and 10, we will change chi 9
# chitrunc = 10
# Replacing A[8](10, 5, 2) with (10, 10, 2)
# Replacing A[9](5, 5, 2) with (10, 5, 2)
# updating left env, 8 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 9 and 11, we will change chi 10
# chitrunc = 10
# Replacing A[9](10, 5, 2) with (10, 10, 2)
# Replacing A[10](5, 5, 2) with (10, 5, 2)
# updating left env, 9 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 10 and 12, we will change chi 11
# chitrunc = 10
# Replacing A[10](10, 5, 2) with (10, 10, 2)
# Replacing A[11](5, 5, 2) with (10, 5, 2)
# updating left env, 10 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 11 and 13, we will change chi 12
# chitrunc = 10
# Replacing A[11](10, 5, 2) with (10, 10, 2)
# Replacing A[12](5, 5, 2) with (10, 5, 2)
# updating left env, 11 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 12 and 14, we will change chi 13
# chitrunc = 10
# Replacing A[12](10, 5, 2) with (10, 10, 2)
# Replacing A[13](5, 5, 2) with (10, 5, 2)
# updating left env, 12 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 13 and 15, we will change chi 14
# chitrunc = 10
# Replacing A[13](10, 5, 2) with (10, 10, 2)
# Replacing A[14](5, 5, 2) with (10, 5, 2)
# updating left env, 13 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 14 and 16, we will change chi 15
# chitrunc = 10
# Replacing A[14](10, 5, 2) with (10, 10, 2)
# Replacing A[15](5, 5, 2) with (10, 5, 2)
# updating left env, 14 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (5, 3, 5)
# chis = 10, 5
# working with chis 15 and 17, we will change chi 16
# chitrunc = 10
# Replacing A[15](10, 5, 2) with (10, 10, 2)
# Replacing A[16](5, 5, 2) with (10, 5, 2)
# updating left env, 15 elem from ..
# (10, 3, 10) (3, 3, 2, 2) (3, 3, 2, 2) (4, 3, 4)
# chis = 10, 4
# working with chis 16 and 18, we will change chi 17
# chitrunc = 8
# Replacing A[16](10, 5, 2) with (10, 8, 2)
# Replacing A[17](5, 4, 2) with (8, 4, 2)
# updating left env, 16 elem from ..
# (8, 3, 8) (3, 3, 2, 2) (3, 3, 2, 2) (2, 3, 2)
# chis = 8, 2
# working with chis 17 and 19, we will change chi 18
# chitrunc = 2
# Replacing A[17](8, 4, 2) with (8, 2, 2)
# Replacing A[18](4, 2, 2) with (2, 2, 2)
# updating left env, 17 elem from ..
# (2, 3, 2) (3, 3, 2, 2) (3, 1, 2, 2) (1, 1, 1)
# chis = 2, 1
# working with chis 18 and 20, we will change chi 19
# chitrunc = 2
# Replacing A[18](2, 2, 2) with (2, 2, 2)
# Replacing A[19](2, 1, 2) with (2, 1, 2)
# updating left env, 18 elem from ..
# (2, 3, 2) (3, 3, 2, 2) (3, 1, 2, 2) (1, 1, 1)
# 2 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/uno/TN/dummyrg/code/stefanoMPS/isingGS_dmrg.ipynb Cell 4 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/uno/TN/dummyrg/code/stefanoMPS/isingGS_dmrg.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> psi = mps.myMPS(mps.randMPS(LLL))
#       <a href='vscode-notebook-cell:/Users/uno/TN/dummyrg/code/stefanoMPS/isingGS_dmrg.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> Hising = mpo.myMPO(IsingMPO(LLL, J=1., g=gg))
# ----> <a href='vscode-notebook-cell:/Users/uno/TN/dummyrg/code/stefanoMPS/isingGS_dmrg.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> dmrg.findGS_DMRG(Hising, psi)
#
# File ~/TN/dummyrg/code/stefanoMPS/myDMRG.py:91, in findGS_DMRG(inMPO, inMPS)
#      88 Apsi[rjj] = ssv
#      90 # rebuild right env #TODO: do update instead of full rebuild
# ---> 91 re = mpomps.build_right_env(inMPS,inMPO)
#      92 Emin = Emin + lam0
#
# File ~/TN/dummyrg/code/stefanoMPS/applMPOMPS.py:103, in build_right_env(psi, o, j)
#     100 for jj, (Bj, Wj) in enumerate(zip(psi.MPS[::-1], o.MPO[::-1])):
#     101     # mps: vL vR p*  | mpo : vL vR pU pD*
#     102     rjj = -jj-1
# --> 103     temp = ncon([Bj, right_env[rjj]], [[-3,1,-4],[-1,-2,1]])
#     104     temp = ncon([Wj, temp],[[-2,2,-4,4],[-1,2,-3,4]])
#     105     right_env[rjj-1] = ncon([np.conj(Bj),temp],[[-1,1,4],[1,-2,-3,4]])
#
# File /usr/local/lib/python3.9/site-packages/tensornetwork/ncon_interface.py:634, in ncon(tensors, network_structure, con_order, out_order, check_network, backend)
#     632 _tensors = [backend_obj.convert_to_tensor(t) for t in _tensors]
#     633 if check_network:
# --> 634   _check_network(network_structure, [t.shape for t in _tensors], con_order,
#     635                  out_order)
#     636 network_structure, mapping = _canonicalize_network_structure(
#     637     network_structure)
#     638 flat_labels = [l for sublist in network_structure for l in sublist]
#
# File /usr/local/lib/python3.9/site-packages/tensornetwork/ncon_interface.py:237, in _check_network(network_structure, tensor_dimensions, con_order, out_order)
#     234     mismatched_labels.append(l)
#     236 if len(mismatched_labels) > 0:
# --> 237   raise ValueError(
#     238       f"tensor dimensions for labels {mismatched_labels} are mismatching")
#
# ValueError: tensor dimensions for labels [1] are mismatching
